# %% [markdown]
# Operators
# 1. Arithmetic Operator
# 2. Assignment Operator
# 3. Relational Operator
# 4. Logical Operator
# 5. Unary Operator

# %% [markdown]
# Testcase1: Arithmetic Operator

# %%
x1, y1 = 10, 5

# %%
print(x1+y1)
print(x1-y1)
print(x1*y1)
print(x1/y1)
print(x1//y1)
print(x1%y1)
print(x1**y1)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %% [markdown]
# Testcase2: Assignment Operator

# %%
x = 2

# %%
x = x + 2

# %%
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x += 2
x
# Out:
# 8

# %%
x -= 2
x
# Out:
# 6

# %%
x *= 2
x
# Out:
# 12

# %%
x /= 2
x
# Out:
# 6.0

# %%
x //= 2
x
# Out:
# 3.0

# %%
a, b = 5, 6

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %% [markdown]
# Testcase3: Relational Operator

# %%
a = 5
b = 6

# %%
print(a < b)
print(a > b)
print(a <= b)
print(a >= b)
print(a == b)
print(a != b)
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# Testcase4: Logical Operator

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 and b < 2
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
a > 8 or b < 2
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True

# %% [markdown]
# Testcase5: Unary Operator

# %%
n = 7
n
# Out:
# 7

# %%
m = (-n)
m
# Out:
# -7

# %%
n
# Out:
# 7

# %%
-n
# Out:
# -7
