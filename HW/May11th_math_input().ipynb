# %%
import math

# %%
x = math.sqrt(16) 
print(x)
# Out:
# 4.0

# %%
x1 = math.sqrt(25)
print(x1)
# Out:
# 5.0

# %%
print(math.floor(3.7))
# Out:
# 3

# %%
print(math.ceil(3.7))
# Out:
# 4

# %%
print(math.pow(2, 3))
# Out:
# 8.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
import math as m
print(m.sqrt(16))
# Out:
# 4.0

# %%
from math import sqrt, pow

# %%
pow(2, 3)
# Out:
# 8.0

# %%
round(pow(2, 3))
# Out:
# 8
