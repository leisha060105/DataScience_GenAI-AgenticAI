# %%
x = 25

# %%
bin(x)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
print(oct(x))
print(hex(x))
# Out:
# 0o31
# 0x19

# %%
hex(50)
# Out:
# '0x32'

# %%
~21
# Out:
# -22

# %%
~3
# Out:
# -4

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
1 & 0
# Out:
# 0

# %%
1 | 0
# Out:
# 1

# %%
12^13
# Out:
# 1

# %%
1^2
# Out:
# 3

# %%
40^34
# Out:
# 10

# %%
10<<1
# Out:
# 20

# %%
10<<2
# Out:
# 40

# %%
10>>1
# Out:
# 5
