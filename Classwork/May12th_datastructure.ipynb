# %%
l = []
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l1 = [10, 20, 30]
l1
# Out:
# [10, 20, 30]

# %%
len(l1)
# Out:
# 3

# %%
l1.append(40)
l1.append(50)
l1.append(60)
l1.append(10)
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
len(l1)
# Out:
# 7

# %%
l1.append(70,80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l1.append(70,80)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l1.append(['a', 'b', 'c'])
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l2 = [34, 5.3, 'nit', 1+2j, True]

# %%
l2
# Out:
# [34, 5.3, 'nit', (1+2j), True]

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'nit', (1+2j), True]

# %%
print(len(l))
print(len(l1))
print(len(l2))
# Out:
# 0
# 8
# 5

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 2387413792000
# 2387413928768
# 2387414858816

# %%
print(type(l))
print(type(l1))
print(type(l2))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
#list membership

10 in l1
# Out:
# True

# %%
['a', 'b', 'c'] in l1
# Out:
# True

# %%
100 in l1
# Out:
# False

# %%
l2
# Out:
# [34, 5.3, 'nit', (1+2j), True]

# %%
l3 = l2.copy()
l3
# Out:
# [34, 5.3, 'nit', (1+2j), True]

# %%
print(id(l2))
print(id(l3))
# Out:
# 2387414858816
# 2387415646976

# %%
print(l)
print(l1)
print(l2)
print(l3)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'nit', (1+2j), True]
# [34, 5.3, 'nit', (1+2j), True]

# %%
len(l3)
# Out:
# 5

# %%
l3.clear()
print(l3)
# Out:
# []

# %%
len(l3)
# Out:
# 0

# %%
del l3

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'nit', (1+2j), True]

# %%
l2.count(5.3)
# Out:
# 1

# %%
l1.count(10)
# Out:
# 2

# %%
l1[:]
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[:-1]
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l1[-1]
# Out:
# ['a', 'b', 'c']

# %%
l1[0:10:3]
# Out:
# [10, 40, 10]

# %%
l1[::1]
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[::2]
# Out:
# [10, 30, 50, 10]

# %%
l1[::3]
# Out:
# [10, 40, 10]

# %%
l1[::-1]
# Out:
# [['a', 'b', 'c'], 10, 60, 50, 40, 30, 20, 10]

# %%
l1[::-2]
# Out:
# [['a', 'b', 'c'], 60, 40, 20]

# %%
l1[::-3]
# Out:
# [['a', 'b', 'c'], 50, 20]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[4:-3]
# Out:
# [50]
