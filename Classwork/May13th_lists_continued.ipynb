# %%
l = []
l1 = [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]
l2 = [34, 5.3, 'nit', 1+2j, True]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[0]
# Out:
# 10

# %%
l1[0] = 100

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[-1] = 'leisha vishwanath'

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath']

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath']
# [34, 5.3, 'nit', (1+2j), True]

# %%
l.extend(l2)

# %%
print(l)
print(l1)
print(l2)
# Out:
# [34, 5.3, 'nit', (1+2j), True]
# [100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath']
# [34, 5.3, 'nit', (1+2j), True]

# %%
l.extend(l1)

# %%
print(l)
# Out:
# [34, 5.3, 'nit', (1+2j), True, 100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath']

# %%
l.index('nit')
# Out:
# 2

# %%
l1.append(10)

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath', 10]

# %%
l1.index(10)
# Out:
# 6

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath', 10]

# %%
l1.insert(2, 25)

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10, 'leisha vishwanath', 10]

# %%
l1.pop()
# Out:
# 10

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10, 'leisha vishwanath']

# %%
l1.pop()
# Out:
# 'leisha vishwanath'

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10]

# %%
l.pop(2)
# Out:
# 'nit'

# %%
l
# Out:
# [34, 5.3, (1+2j), True, 100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath']

# %%
l[3]
# Out:
# True

# %%
l
# Out:
# [34, 5.3, (1+2j), True, 100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath']

# %%
l.remove(1+2j)

# %%
l
# Out:
# [34, 5.3, True, 100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath']

# %%
l.reverse()
l
# Out:
# ['leisha vishwanath', 10, 60, 50, 40, 30, 20, 100, True, 5.3, 34]

# %%
l
# Out:
# ['leisha vishwanath', 10, 60, 50, 40, 30, 20, 100, True, 5.3, 34]

# %%
l.reverse()
l
# Out:
# [34, 5.3, True, 100, 20, 30, 40, 50, 60, 10, 'leisha vishwanath']

# %%
l.sort

# %%
l2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 l2.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10]

# %%
l1.sort()

# %%
l1
# Out:
# [10, 20, 25, 30, 40, 50, 60, 100]

# %%
l1.sort(reverse=True)
l1
# Out:
# [100, 60, 50, 40, 30, 25, 20, 10]

# %%
l3 = [3,1,2]
l3
# Out:
# [3, 1, 2]

# %%
l3.sort() #parameter tuning
l3
#the default is set so that means it is parametetr tuning.
# Out:
# [1, 2, 3]

# %%
l3.sort(reverse=True) #hyperparameter tuning
l3
#user physically changes the parameters which is hyperparameter tuning.
# Out:
# [3, 2, 1]

# %%
l2
# Out:
# [34, 5.3, 'nit', (1+2j), True]

# %%
l2[2][0]
# Out:
# 'n'

# %%
print(l2[2][0])
print(l2[2][1])
print(l2[2][2])
# Out:
# n
# i
# t

# %%
l
# Out:
# [True, 5.3, 10, 20, 30, 34, 40, 50, 60, 100, 'leisha vishwanath']

# %%
for i in l:
    print(i)
# Out:
# True
# 5.3
# 10
# 20
# 30
# 34
# 40
# 50
# 60
# 100
# leisha vishwanath

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, True)
# (1, 5.3)
# (2, 10)
# (3, 20)
# (4, 30)
# (5, 34)
# (6, 40)
# (7, 50)
# (8, 60)
# (9, 100)
# (10, 'leisha vishwanath')

# %%
l1
# Out:
# [100, 60, 50, 40, 30, 25, 20, 10]

# %%
all(l1)
# Out:
# True

# %%
any(l1)
# Out:
# True

# %%
l1.append(0)

# %%
all(l1)
# Out:
# False

# %%
any(l1)
# Out:
# True
